# %% [markdown]
# <a href="https://colab.research.google.com/github/Yahonov/Pyton/blob/main/dz_10sem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import random
lst = ['robot'] * 10
lst += ['human'] * 10
random.shuffle(lst)
data = pd.DataFrame({'whoAmI':lst})
data.head()
# Out:
#   whoAmI
# 0  robot
# 1  human
# 2  human
# 3  human
# 4  robot

# %%
data
# Out:
#    whoAmI
# 0   robot
# 1   human
# 2   human
# 3   human
# 4   robot
# 5   human
# 6   human
# 7   robot
# 8   robot
# 9   robot
# 10  human
# 11  human
# 12  human
# 13  robot
# 14  robot
# 15  robot
# 16  robot
# 17  human
# 18  robot
# 19  human

# %%
data.loc[data['whoAmI'] == 'human', 'human'] = '1'

# %%
data
# Out:
#    whoAmI human
# 0   robot   NaN
# 1   human     1
# 2   human     1
# 3   human     1
# 4   robot   NaN
# 5   human     1
# 6   human     1
# 7   robot   NaN
# 8   robot   NaN
# 9   robot   NaN
# 10  human     1
# 11  human     1
# 12  human     1
# 13  robot   NaN
# 14  robot   NaN
# 15  robot   NaN
# 16  robot   NaN
# 17  human     1
# 18  robot   NaN
# 19  human     1

# %%
data.loc[data['whoAmI'] != 'human', 'human'] = '0'

# %%
data
# Out:
#    whoAmI human
# 0   robot     0
# 1   human     1
# 2   human     1
# 3   human     1
# 4   robot     0
# 5   human     1
# 6   human     1
# 7   robot     0
# 8   robot     0
# 9   robot     0
# 10  human     1
# 11  human     1
# 12  human     1
# 13  robot     0
# 14  robot     0
# 15  robot     0
# 16  robot     0
# 17  human     1
# 18  robot     0
# 19  human     1

# %%
data.drop(columns='whoAmI')
# Out:
#    human
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
# 5      1
# 6      1
# 7      0
# 8      0
# 9      0
# 10     1
# 11     1
# 12     1
# 13     0
# 14     0
# 15     0
# 16     0
# 17     1
# 18     0
# 19     1
