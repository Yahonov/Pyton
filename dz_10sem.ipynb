# %% [markdown]
# <a href="https://colab.research.google.com/github/Yahonov/Pyton/blob/main/dz_10sem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import random
lst = ['robot'] * 10
lst += ['human'] * 10
random.shuffle(lst)
data = pd.DataFrame({'whoAmI':lst})
data.head()
# Out:
#   whoAmI
# 0  human
# 1  human
# 2  human
# 3  human
# 4  robot

# %%
data
# Out:
#    whoAmI
# 0   human
# 1   human
# 2   human
# 3   human
# 4   robot
# 5   robot
# 6   robot
# 7   human
# 8   human
# 9   human
# 10  robot
# 11  human
# 12  human
# 13  robot
# 14  robot
# 15  human
# 16  robot
# 17  robot
# 18  robot
# 19  robot

# %%
data.loc[data['whoAmI'] == 'human', 'who'] = '1'

# %%
data
# Out:
#    whoAmI  who
# 0   human    1
# 1   human    1
# 2   human    1
# 3   human    1
# 4   robot  NaN
# 5   robot  NaN
# 6   robot  NaN
# 7   human    1
# 8   human    1
# 9   human    1
# 10  robot  NaN
# 11  human    1
# 12  human    1
# 13  robot  NaN
# 14  robot  NaN
# 15  human    1
# 16  robot  NaN
# 17  robot  NaN
# 18  robot  NaN
# 19  robot  NaN

# %%
data.loc[data['whoAmI'] != 'human', 'who'] = '0'

# %%
data
# Out:
#    whoAmI who
# 0   human   1
# 1   human   1
# 2   human   1
# 3   human   1
# 4   robot   0
# 5   robot   0
# 6   robot   0
# 7   human   1
# 8   human   1
# 9   human   1
# 10  robot   0
# 11  human   1
# 12  human   1
# 13  robot   0
# 14  robot   0
# 15  human   1
# 16  robot   0
# 17  robot   0
# 18  robot   0
# 19  robot   0

# %%
data.drop(columns='whoAmI')
# Out:
#    who
# 0    1
# 1    1
# 2    1
# 3    1
# 4    0
# 5    0
# 6    0
# 7    1
# 8    1
# 9    1
# 10   0
# 11   1
# 12   1
# 13   0
# 14   0
# 15   1
# 16   0
# 17   0
# 18   0
# 19   0
